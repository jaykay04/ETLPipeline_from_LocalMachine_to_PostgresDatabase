# %%
import psycopg2
import pandas as pd
import pandas.io.sql as sqlio

# %% [markdown]
# ## Bulk Load product data from csv into Postgres Database

# %%
# Create a connection to postgres database
conn = psycopg2.connect(dbname="jaykay_db",user="postgres",password="Chelseablue2@",host="localhost")

# Then open a cursor to perform database operations
cur = conn.cursor()

# %%
# Lets write a create table query to create product table
create_table = """CREATE TABLE product(
        id SERIAL PRIMARY KEY,
        name VARCHAR(255),
        price FLOAT,
        stock INTEGER
)
"""

# %%
# Execute the query to create a table in jaykay_db database
cur.execute(create_table)
conn.commit()

# %%
# Now we have our table, we can then execute the copy command to bulk load the data into the product table
copy_command = """
    COPY product(id,name,price,stock) 
    FROM '/Users/Jaykay/Downloads/Product.csv' CSV HEADER;
"""

cur.execute(copy_command)
conn.commit()

# %% [markdown]
# ## Extract, Transform and Load Superstore Data into Postgres Database

# %%
file_path = "/Users/Jaykay/Downloads/superstore.csv"
df = pd.read_csv(file_path,encoding="unicode_escape")

# Check the first 5 records
df.head()
# Out:
#          Order ID     Order Line ID  Order Date   Ship Date       Ship Mode  \
# 0  CA-2016-152156  CA-2016-152156-1   11/8/2016  11/11/2016    Second Class
# 1  CA-2016-152156  CA-2016-152156-2   11/8/2016  11/11/2016    Second Class
# 2  CA-2016-138688  CA-2016-138688-1   6/12/2016   6/16/2016    Second Class
# 3  US-2015-108966  US-2015-108966-1  10/11/2015  10/18/2015  Standard Class
# 4  US-2015-108966  US-2015-108966-2  10/11/2015  10/18/2015  Standard Class
#
#   Order Priority Customer ID    Customer Name              Customer Email  \
# 0         Medium    CG-12520      Claire Gute     claire.gute@hotmail.com
# 1            Low    CG-12520      Claire Gute     claire.gute@hotmail.com
# 2       Critical    DV-13045  Darrin Van Huff     darrin.huff@hotmail.com
# 3            Low    SO-20335   Sean O'Donnell  sean.o'donnell@hotmail.com
# 4            Low    SO-20335   Sean O'Donnell  sean.o'donnell@hotmail.com
#
#   Gender  ... Postal Code Region       Product ID         Category  \
# 0      F  ...       42420  South  FUR-BO-10001798        Furniture
# 1      F  ...       42420  South  FUR-CH-10000454        Furniture
# 2      M  ...       90036   West  OFF-LA-10000240  Office Supplies
# 3      M  ...       33311  South  FUR-TA-10000577        Furniture
# 4      M  ...       33311  South  OFF-ST-10000760  Office Supplies
#
#   Sub-Category                                       Product Name     Sales  \
# 0    Bookcases                  Bush Somerset Collection Bookcase  261.9600
# 1       Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2       Labels  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3       Tables      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4      Storage                     Eldon Fold 'N Roll Cart System   22.3680
#
#   Quantity Discount    Profit
# 0        2     0.00   41.9136
# 1        3     0.00  219.5820
# 2        2     0.00    6.8714
# 3        5     0.45 -383.0310
# 4        2     0.20    2.5164
#
# [5 rows x 25 columns]

# %%
# Check the data types of each field
df.dtypes
# Out:
# Order ID           object
# Order Line ID      object
# Order Date         object
# Ship Date          object
# Ship Mode          object
# Order Priority     object
# Customer ID        object
# Customer Name      object
# Customer Email     object
# Gender             object
# Birth Date         object
# Segment            object
# Country            object
# City               object
# State              object
# Postal Code         int64
# Region             object
# Product ID         object
# Category           object
# Sub-Category       object
# Product Name       object
# Sales             float64
# Quantity            int64
# Discount          float64
# Profit            float64
# dtype: object

# %%
# Check the number of records and fields in the data
df.shape
# Out:
# (9994, 25)

# %%
df.convert_dtypes()
df.dtypes
# Out:
# Order ID           object
# Order Line ID      object
# Order Date         object
# Ship Date          object
# Ship Mode          object
# Order Priority     object
# Customer ID        object
# Customer Name      object
# Customer Email     object
# Gender             object
# Birth Date         object
# Segment            object
# Country            object
# City               object
# State              object
# Postal Code         int64
# Region             object
# Product ID         object
# Category           object
# Sub-Category       object
# Product Name       object
# Sales             float64
# Quantity            int64
# Discount          float64
# Profit            float64
# dtype: object

# %%
# Convert the Postal Code from Integer to string
df["Postal Code"] = df["Postal Code"].astype(str)
df.dtypes
# Out:
# Order ID           object
# Order Line ID      object
# Order Date         object
# Ship Date          object
# Ship Mode          object
# Order Priority     object
# Customer ID        object
# Customer Name      object
# Customer Email     object
# Gender             object
# Birth Date         object
# Segment            object
# Country            object
# City               object
# State              object
# Postal Code        object
# Region             object
# Product ID         object
# Category           object
# Sub-Category       object
# Product Name       object
# Sales             float64
# Quantity            int64
# Discount          float64
# Profit            float64
# dtype: object

# %%
# Convert the Order Date to datetime
df["Order Date"] = pd.to_datetime(df["Order Date"])
df.dtypes
# Out:
# Order ID                  object
# Order Line ID             object
# Order Date        datetime64[ns]
# Ship Date                 object
# Ship Mode                 object
# Order Priority            object
# Customer ID               object
# Customer Name             object
# Customer Email            object
# Gender                    object
# Birth Date                object
# Segment                   object
# Country                   object
# City                      object
# State                     object
# Postal Code               object
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# dtype: object

# %%
# Convert multiple fields to datetime
df[["Ship Date","Birth Date"]] = df[["Ship Date","Birth Date"]].apply(pd.to_datetime)
df.dtypes
# Out:
# Order ID                  object
# Order Line ID             object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Order Priority            object
# Customer ID               object
# Customer Name             object
# Customer Email            object
# Gender                    object
# Birth Date        datetime64[ns]
# Segment                   object
# Country                   object
# City                      object
# State                     object
# Postal Code               object
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Line ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Order Priority', 'Customer ID', 'Customer Name', 'Customer Email',
#        'Gender', 'Birth Date', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df["Unit Price"] = df["Sales"]/df["Quantity"]
df.head()
# Out:
#          Order ID     Order Line ID Order Date  Ship Date       Ship Mode  \
# 0  CA-2016-152156  CA-2016-152156-1 2016-11-08 2016-11-11    Second Class
# 1  CA-2016-152156  CA-2016-152156-2 2016-11-08 2016-11-11    Second Class
# 2  CA-2016-138688  CA-2016-138688-1 2016-06-12 2016-06-16    Second Class
# 3  US-2015-108966  US-2015-108966-1 2015-10-11 2015-10-18  Standard Class
# 4  US-2015-108966  US-2015-108966-2 2015-10-11 2015-10-18  Standard Class
#
#   Order Priority Customer ID    Customer Name              Customer Email  \
# 0         Medium    CG-12520      Claire Gute     claire.gute@hotmail.com
# 1            Low    CG-12520      Claire Gute     claire.gute@hotmail.com
# 2       Critical    DV-13045  Darrin Van Huff     darrin.huff@hotmail.com
# 3            Low    SO-20335   Sean O'Donnell  sean.o'donnell@hotmail.com
# 4            Low    SO-20335   Sean O'Donnell  sean.o'donnell@hotmail.com
#
#   Gender  ... Region       Product ID         Category Sub-Category  \
# 0      F  ...  South  FUR-BO-10001798        Furniture    Bookcases
# 1      F  ...  South  FUR-CH-10000454        Furniture       Chairs
# 2      M  ...   West  OFF-LA-10000240  Office Supplies       Labels
# 3      M  ...  South  FUR-TA-10000577        Furniture       Tables
# 4      M  ...  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400        3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200        2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775        5
# 4                     Eldon Fold 'N Roll Cart System   22.3680        2
#
#   Discount    Profit Unit Price
# 0     0.00   41.9136   130.9800
# 1     0.00  219.5820   243.9800
# 2     0.00    6.8714     7.3100
# 3     0.45 -383.0310   191.5155
# 4     0.20    2.5164    11.1840
#
# [5 rows x 26 columns]

# %%
df.shape
# Out:
# (9994, 26)

# %%
df.dtypes
# Out:
# Order ID                  object
# Order Line ID             object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Order Priority            object
# Customer ID               object
# Customer Name             object
# Customer Email            object
# Gender                    object
# Birth Date        datetime64[ns]
# Segment                   object
# Country                   object
# City                      object
# State                     object
# Postal Code               object
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Unit Price               float64
# dtype: object

# %%
conn.rollback()

# %%
conn.autocommit=True

# %%
# We can also use this line of code
# from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT
# conn.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# %%
# Lets create and execute superstore table in jaykay_db
create_superstore_table = """CREATE TABLE superstore(
        OrderID VARCHAR(255),
        OrderLineID VARCHAR(255),
        OrderDate DATE,
        ShipDate DATE,
        ShipMode VARCHAR(255),
        OrderPriority VARCHAR(255),
        CustomerID VARCHAR(255),
        CustomerName VARCHAR(255),
        CustomerEmail VARCHAR(255),
        Gender VARCHAR(255),
        BirthDate DATE,
        Segment VARCHAR(255),
        Country VARCHAR(255),
        City VARCHAR(255),
        State VARCHAR(255),
        PostalCode VARCHAR(255),
        Region VARCHAR(255),
        ProductID VARCHAR(255),
        Category VARCHAR(255),
        SubCategory VARCHAR(255),
        ProductName VARCHAR(255),
        Sales FLOAT,
        Quantity INTEGER,
        Discount FLOAT,
        Profit FLOAT,
        UnitPrice FLOAT
)
"""

cur.execute(create_superstore_table)
conn.commit()

# %%
# Lets check the database we are using
cur.execute("SELECT current_database()")
cur.fetchone() # we can also use cur.fetchall()
# Out:
# ('jaykay_db',)

# %%
# Close Connection
conn.close()

# %% [markdown]
# ### Load the superstore dataframe to jaykay_db in postgres

# %%
# we need to import sqlalchemy

from sqlalchemy import create_engine

# %%
# Create a connection to postgres database
conn = psycopg2.connect(dbname="jaykay_db",user="postgres",password="jaykayboss",host="localhost")

# Then open a cursor to perform database operations
cur = conn.cursor()

# %%
# Let us create the engine
#Connection string: dialect+driver://user:password@server/database

engine = create_engine('postgresql+psycopg2://postgres:jaykayboss@localhost/jaykay_db')

# %%
# Display engine info
engine
# Out:
# Engine(postgresql+psycopg2://postgres:***@localhost/jaykay_db)

# %%
df.head()
# Out:
#          Order ID     Order Line ID Order Date  Ship Date       Ship Mode  \
# 0  CA-2016-152156  CA-2016-152156-1 2016-11-08 2016-11-11    Second Class
# 1  CA-2016-152156  CA-2016-152156-2 2016-11-08 2016-11-11    Second Class
# 2  CA-2016-138688  CA-2016-138688-1 2016-06-12 2016-06-16    Second Class
# 3  US-2015-108966  US-2015-108966-1 2015-10-11 2015-10-18  Standard Class
# 4  US-2015-108966  US-2015-108966-2 2015-10-11 2015-10-18  Standard Class
#
#   Order Priority Customer ID    Customer Name              Customer Email  \
# 0         Medium    CG-12520      Claire Gute     claire.gute@hotmail.com
# 1            Low    CG-12520      Claire Gute     claire.gute@hotmail.com
# 2       Critical    DV-13045  Darrin Van Huff     darrin.huff@hotmail.com
# 3            Low    SO-20335   Sean O'Donnell  sean.o'donnell@hotmail.com
# 4            Low    SO-20335   Sean O'Donnell  sean.o'donnell@hotmail.com
#
#   Gender  ... Region       Product ID         Category Sub-Category  \
# 0      F  ...  South  FUR-BO-10001798        Furniture    Bookcases
# 1      F  ...  South  FUR-CH-10000454        Furniture       Chairs
# 2      M  ...   West  OFF-LA-10000240  Office Supplies       Labels
# 3      M  ...  South  FUR-TA-10000577        Furniture       Tables
# 4      M  ...  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400        3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200        2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775        5
# 4                     Eldon Fold 'N Roll Cart System   22.3680        2
#
#   Discount    Profit Unit Price
# 0     0.00   41.9136   130.9800
# 1     0.00  219.5820   243.9800
# 2     0.00    6.8714     7.3100
# 3     0.45 -383.0310   191.5155
# 4     0.20    2.5164    11.1840
#
# [5 rows x 26 columns]

# %%
# Now lets load the table with the dataframe
df.to_sql('superstore', engine, if_exists = 'replace', index=False) #if_exists can take append, replace & fail
# Out:
# 994

# %% [markdown]
# ### Load unemployment data from dataframe to postgres

# %%
path = "/Users/Jaykay/Downloads/unemployment.xlsx"
df1 = pd.read_excel(path)
df1.head()
# Out:
#               Age Gender     Period  Unemployed
# 0  16 to 19 years    Men 2005-01-01       91000
# 1  20 to 24 years    Men 2005-01-01      175000
# 2  25 to 34 years    Men 2005-01-01      194000
# 3  35 to 44 years    Men 2005-01-01      201000
# 4  45 to 54 years    Men 2005-01-01      207000

# %%
df1.shape
# Out:
# (1708, 4)

# %%
df1.dtypes
# Out:
# Age                   object
# Gender                object
# Period        datetime64[ns]
# Unemployed             int64
# dtype: object

# %%
#Create table
unemp_table = """
    CREATE TABLE unemployment(
    Age VARCHAR(255),
    Gender VARCHAR(255),
    Period DATE,
    Unemployyed INTEGER
    )
"""
cur.execute(unemp_table)
conn.commit()

# %%
# Now lets load the table with the dataframe
df1.to_sql('unemployment', engine, if_exists = 'replace', index=False) #if_exists can take append, replace & fail
# Out:
# 708

# %%
# For Millions of Records, we might want to load it in chunks

for x in pd.read_csv("/Users/Jaykay/Downloads/superstore.csv", chunksize=1000):
    x.to_sql("superstore", engine, if_exists='replace')

# %%
# Lets query data from postgres and save it to a dataframe
# We have two methods, 1. conn.execute("SQL QUERY") 2. pd.read_sql_query("SQL QUERY")

superstore_df = pd.read_sql_query("SELECT * FROM superstore LIMIT 50", engine)
superstore_df
# Out:
#           Order ID     Order Line ID Order Date  Ship Date       Ship Mode  \
# 0   CA-2016-152156  CA-2016-152156-1 2016-11-08 2016-11-11    Second Class
# 1   CA-2016-152156  CA-2016-152156-2 2016-11-08 2016-11-11    Second Class
# 2   CA-2016-138688  CA-2016-138688-1 2016-06-12 2016-06-16    Second Class
# 3   US-2015-108966  US-2015-108966-1 2015-10-11 2015-10-18  Standard Class
# 4   US-2015-108966  US-2015-108966-2 2015-10-11 2015-10-18  Standard Class
# 5   CA-2014-115812  CA-2014-115812-1 2014-06-09 2014-06-14  Standard Class
# 6   CA-2014-115812  CA-2014-115812-2 2014-06-09 2014-06-14  Standard Class
# 7   CA-2014-115812  CA-2014-115812-3 2014-06-09 2014-06-14  Standard Class
# 8   CA-2014-115812  CA-2014-115812-4 2014-06-09 2014-06-14  Standard Class
# 9   CA-2014-115812  CA-2014-115812-5 2014-06-09 2014-06-14  Standard Class
# 10  CA-2014-115812  CA-2014-115812-6 2014-06-09 2014-06-14  Standard Class
# 11  CA-2014-115812  CA-2014-115812-7 2014-06-09 2014-06-14  Standard Class
# 12  CA-2017-114412  CA-2017-114412-1 2017-04-15 2017-04-20  Standard Class
# 13  CA-2016-161389  CA-2016-161389-1 2016-12-05 2016-12-10  Standard Class
# 14  US-2015-118983  US-2015-118983-1 2015-11-22 2015-11-26  Standard Class
# 15  US-2015-118983  US-2015-118983-2 2015-11-22 2015-11-26  Standard Class
# 16  CA-2014-105893  CA-2014-105893-1 2014-11-11 2014-11-18  Standard Class
# 17  CA-2014-167164  CA-2014-167164-1 2014-05-13 2014-05-15    Second Class
# 18  CA-2014-143336  CA-2014-143336-1 2014-08-27 2014-09-01    Second Class
# 19  CA-2014-143336  CA-2014-143336-2 2014-08-27 2014-09-01    Second Class
# 20  CA-2014-143336  CA-2014-143336-3 2014-08-27 2014-09-01    Second Class
# 21  CA-2016-137330  CA-2016-137330-1 2016-12-09 2016-12-13  Standard Class
# 22  CA-2016-137330  CA-2016-137330-2 2016-12-09 2016-12-13  Standard Class
# 23  US-2017-156909  US-2017-156909-1 2017-07-16 2017-07-18    Second Class
# 24  CA-2015-106320  CA-2015-106320-1 2015-09-25 2015-09-30  Standard Class
# 25  CA-2016-121755  CA-2016-121755-1 2016-01-16 2016-01-20    Second Class
# 26  CA-2016-121755  CA-2016-121755-2 2016-01-16 2016-01-20    Second Class
# 27  US-2015-150630  US-2015-150630-1 2015-09-17 2015-09-21  Standard Class
# 28  US-2015-150630  US-2015-150630-2 2015-09-17 2015-09-21  Standard Class
# 29  US-2015-150630  US-2015-150630-3 2015-09-17 2015-09-21  Standard Class
# 30  US-2015-150630  US-2015-150630-4 2015-09-17 2015-09-21  Standard Class
# 31  US-2015-150630  US-2015-150630-5 2015-09-17 2015-09-21  Standard Class
# 32  US-2015-150630  US-2015-150630-6 2015-09-17 2015-09-21  Standard Class
# 33  US-2015-150630  US-2015-150630-7 2015-09-17 2015-09-21  Standard Class
# 34  CA-2017-107727  CA-2017-107727-1 2017-10-19 2017-10-23    Second Class
# 35  CA-2016-117590  CA-2016-117590-1 2016-12-08 2016-12-10     First Class
# 36  CA-2016-117590  CA-2016-117590-2 2016-12-08 2016-12-10     First Class
# 37  CA-2015-117415  CA-2015-117415-1 2015-12-27 2015-12-31  Standard Class
# 38  CA-2015-117415  CA-2015-117415-2 2015-12-27 2015-12-31  Standard Class
# 39  CA-2015-117415  CA-2015-117415-3 2015-12-27 2015-12-31  Standard Class
# 40  CA-2015-117415  CA-2015-117415-4 2015-12-27 2015-12-31  Standard Class
# 41  CA-2017-120999  CA-2017-120999-1 2017-09-10 2017-09-15  Standard Class
# 42  CA-2016-101343  CA-2016-101343-1 2016-07-17 2016-07-22  Standard Class
# 43  CA-2017-139619  CA-2017-139619-1 2017-09-19 2017-09-23  Standard Class
# 44  CA-2016-118255  CA-2016-118255-1 2016-03-11 2016-03-13     First Class
# 45  CA-2016-118255  CA-2016-118255-2 2016-03-11 2016-03-13     First Class
# 46  CA-2014-146703  CA-2014-146703-1 2014-10-20 2014-10-25    Second Class
# 47  CA-2016-169194  CA-2016-169194-1 2016-06-20 2016-06-25  Standard Class
# 48  CA-2016-169194  CA-2016-169194-2 2016-06-20 2016-06-25  Standard Class
# 49  CA-2015-115742  CA-2015-115742-1 2015-04-18 2015-04-22  Standard Class
#
#    Order Priority Customer ID       Customer Name  \
# 0          Medium    CG-12520         Claire Gute
# 1             Low    CG-12520         Claire Gute
# 2        Critical    DV-13045     Darrin Van Huff
# 3             Low    SO-20335      Sean O'Donnell
# 4             Low    SO-20335      Sean O'Donnell
# 5   Not Specified    BH-11710     Brosina Hoffman
# 6          Medium    BH-11710     Brosina Hoffman
# 7        Critical    BH-11710     Brosina Hoffman
# 8        Critical    BH-11710     Brosina Hoffman
# 9        Critical    BH-11710     Brosina Hoffman
# 10           High    BH-11710     Brosina Hoffman
# 11            Low    BH-11710     Brosina Hoffman
# 12  Not Specified    AA-10480        Andrew Allen
# 13            Low    IM-15070        Irene Maddox
# 14       Critical    HP-14815       Harold Pawlan
# 15         Medium    HP-14815       Harold Pawlan
# 16       Critical    PK-19075           Pete Kriz
# 17           High    AG-10270     Alejandro Grove
# 18       Critical    ZD-21925  Zuschuss Donatelli
# 19         Medium    ZD-21925  Zuschuss Donatelli
# 20       Critical    ZD-21925  Zuschuss Donatelli
# 21            Low    KB-16585           Ken Black
# 22  Not Specified    KB-16585           Ken Black
# 23           High    SF-20065     Sandra Flanagan
# 24           High    EB-13870         Emily Burns
# 25       Critical    EH-13945       Eric Hoffmann
# 26         Medium    EH-13945       Eric Hoffmann
# 27  Not Specified    TB-21520     Tracy Blumstein
# 28           High    TB-21520     Tracy Blumstein
# 29  Not Specified    TB-21520     Tracy Blumstein
# 30  Not Specified    TB-21520     Tracy Blumstein
# 31  Not Specified    TB-21520     Tracy Blumstein
# 32           High    TB-21520     Tracy Blumstein
# 33       Critical    TB-21520     Tracy Blumstein
# 34            Low    MA-17560        Matt Abelman
# 35         Medium    GH-14485           Gene Hale
# 36  Not Specified    GH-14485           Gene Hale
# 37           High    SN-20710        Steve Nguyen
# 38       Critical    SN-20710        Steve Nguyen
# 39       Critical    SN-20710        Steve Nguyen
# 40  Not Specified    SN-20710        Steve Nguyen
# 41            Low    LC-16930      Linda Cazamias
# 42         Medium    RA-19885        Ruben Ausman
# 43            Low    ES-14080          Erin Smith
# 44  Not Specified    ON-18715       Odella Nelson
# 45           High    ON-18715       Odella Nelson
# 46       Critical    PO-18865   Patrick O'Donnell
# 47       Critical    LH-16900      Lena Hernandez
# 48            Low    LH-16900      Lena Hernandez
# 49           High    DP-13000       Darren Powers
#
#                     Customer Email Gender  ...   Region       Product ID  \
# 0          claire.gute@hotmail.com      F  ...    South  FUR-BO-10001798
# 1          claire.gute@hotmail.com      F  ...    South  FUR-CH-10000454
# 2          darrin.huff@hotmail.com      M  ...     West  OFF-LA-10000240
# 3       sean.o'donnell@hotmail.com      M  ...    South  FUR-TA-10000577
# 4       sean.o'donnell@hotmail.com      M  ...    South  OFF-ST-10000760
# 5      brosina.hoffman@hotmail.com      M  ...     West  FUR-FU-10001487
# 6      brosina.hoffman@hotmail.com      M  ...     West  OFF-AR-10002833
# 7      brosina.hoffman@hotmail.com      M  ...     West  TEC-PH-10002275
# 8      brosina.hoffman@hotmail.com      M  ...     West  OFF-BI-10003910
# 9      brosina.hoffman@hotmail.com      M  ...     West  OFF-AP-10002892
# 10     brosina.hoffman@hotmail.com      M  ...     West  FUR-TA-10001539
# 11     brosina.hoffman@hotmail.com      M  ...     West  TEC-PH-10002033
# 12        andrew.allen@hotmail.com      F  ...    South  OFF-PA-10002365
# 13        irene.maddox@hotmail.com      M  ...     West  OFF-BI-10003656
# 14       harold.pawlan@hotmail.hom      M  ...  Central  OFF-AP-10002311
# 15       harold.pawlan@hotmail.hom      M  ...  Central  OFF-BI-10000756
# 16           pete.kriz@hotmail.com      M  ...  Central  OFF-ST-10004186
# 17     alejandro.grove@hotmail.com      F  ...     West  OFF-ST-10000107
# 18  zuschuss.donatelli@hotmail.com      F  ...     West  OFF-AR-10003056
# 19  zuschuss.donatelli@hotmail.com      F  ...     West  TEC-PH-10001949
# 20  zuschuss.donatelli@hotmail.com      F  ...     West  OFF-BI-10002215
# 21           ken.black@hotmail.com      F  ...  Central  OFF-AR-10000246
# 22           ken.black@hotmail.com      F  ...  Central  OFF-AP-10001492
# 23     sandra.flanagan@hotmail.com      M  ...     East  FUR-CH-10002774
# 24         emily.burns@hotmail.com      F  ...     West  FUR-TA-10000577
# 25       eric.hoffmann@hotmail.com      M  ...     West  OFF-BI-10001634
# 26       eric.hoffmann@hotmail.com      M  ...     West  TEC-AC-10003027
# 27     tracy.blumstein@hotmail.com      M  ...     East  FUR-BO-10004834
# 28     tracy.blumstein@hotmail.com      M  ...     East  OFF-BI-10000474
# 29     tracy.blumstein@hotmail.com      M  ...     East  FUR-FU-10004848
# 30     tracy.blumstein@hotmail.com      M  ...     East  OFF-EN-10001509
# 31     tracy.blumstein@hotmail.com      M  ...     East  OFF-AR-10004042
# 32     tracy.blumstein@hotmail.com      M  ...     East  OFF-BI-10001525
# 33     tracy.blumstein@hotmail.com      M  ...     East  OFF-AR-10001683
# 34        matt.abelman@hotmail.hom      M  ...  Central  OFF-PA-10000249
# 35           gene.hale@hotmail.com      M  ...  Central  TEC-PH-10004977
# 36           gene.hale@hotmail.com      M  ...  Central  FUR-FU-10003664
# 37        steve.nguyen@hotmail.hom      F  ...  Central  OFF-EN-10002986
# 38        steve.nguyen@hotmail.hom      F  ...  Central  FUR-BO-10002545
# 39        steve.nguyen@hotmail.hom      F  ...  Central  FUR-CH-10004218
# 40        steve.nguyen@hotmail.hom      F  ...  Central  TEC-PH-10000486
# 41      linda.cazamias@hotmail.com      M  ...  Central  TEC-PH-10004093
# 42        ruben.ausman@hotmail.com      M  ...     West  OFF-ST-10003479
# 43          erin.smith@hotmail.com      M  ...    South  OFF-ST-10003282
# 44       odella.nelson@hotmail.com      M  ...  Central  TEC-AC-10000171
# 45       odella.nelson@hotmail.com      M  ...  Central  OFF-BI-10003291
# 46   patrick.o'donnell@hotmail.com      M  ...  Central  OFF-ST-10001713
# 47      lena.hernandez@hotmail.com      M  ...     East  TEC-AC-10002167
# 48      lena.hernandez@hotmail.com      M  ...     East  TEC-PH-10003988
# 49       darren.powers@hotmail.com      M  ...  Central  OFF-BI-10004410
#
#            Category Sub-Category  \
# 0         Furniture    Bookcases
# 1         Furniture       Chairs
# 2   Office Supplies       Labels
# 3         Furniture       Tables
# 4   Office Supplies      Storage
# 5         Furniture  Furnishings
# 6   Office Supplies          Art
# 7        Technology       Phones
# 8   Office Supplies      Binders
# 9   Office Supplies   Appliances
# 10        Furniture       Tables
# 11       Technology       Phones
# 12  Office Supplies        Paper
# 13  Office Supplies      Binders
# 14  Office Supplies   Appliances
# 15  Office Supplies      Binders
# 16  Office Supplies      Storage
# 17  Office Supplies      Storage
# 18  Office Supplies          Art
# 19       Technology       Phones
# 20  Office Supplies      Binders
# 21  Office Supplies          Art
# 22  Office Supplies   Appliances
# 23        Furniture       Chairs
# 24        Furniture       Tables
# 25  Office Supplies      Binders
# 26       Technology  Accessories
# 27        Furniture    Bookcases
# 28  Office Supplies      Binders
# 29        Furniture  Furnishings
# 30  Office Supplies    Envelopes
# 31  Office Supplies          Art
# 32  Office Supplies      Binders
# 33  Office Supplies          Art
# 34  Office Supplies        Paper
# 35       Technology       Phones
# 36        Furniture  Furnishings
# 37  Office Supplies    Envelopes
# 38        Furniture    Bookcases
# 39        Furniture       Chairs
# 40       Technology       Phones
# 41       Technology       Phones
# 42  Office Supplies      Storage
# 43  Office Supplies      Storage
# 44       Technology  Accessories
# 45  Office Supplies      Binders
# 46  Office Supplies      Storage
# 47       Technology  Accessories
# 48       Technology       Phones
# 49  Office Supplies      Binders
#
#                                          Product Name      Sales Quantity  \
# 0                   Bush Somerset Collection Bookcase   261.9600        2
# 1   Hon Deluxe Fabric Upholstered Stacking Chairs,...   731.9400        3
# 2   Self-Adhesive Address Labels for Typewriters b...    14.6200        2
# 3       Bretford CR4500 Series Slim Rectangular Table   957.5775        5
# 4                      Eldon Fold 'N Roll Cart System    22.3680        2
# 5   Eldon Expressions Wood and Plastic Desk Access...    48.8600        7
# 6                                          Newell 322     7.2800        4
# 7                      Mitel 5320 IP Phone VoIP phone   907.1520        6
# 8   DXL Angle-View Binders with Locking Rings by S...    18.5040        3
# 9                    Belkin F5C206VTEL 6 Outlet Surge   114.9000        5
# 10           Chromcraft Rectangular Conference Tables  1706.1840        9
# 11      Konftel 250 Conference phone - Charcoal black   911.4240        4
# 12                                         Xerox 1967    15.5520        3
# 13        Fellowes PB200 Plastic Comb Binding Machine   407.9760        3
# 14  Holmes Replacement Filter for HEPA Air Cleaner...    68.8100        5
# 15   Storex DuraTech Recycled Plastic Frosted Binders     2.5440        3
# 16  Stur-D-Stor Shelving, Vertical 5-Shelf: 72"H x...   665.8800        6
# 17                         Fellowes Super Stor/Drawer    55.5000        2
# 18                                         Newell 341     8.5600        2
# 19                            Cisco SPA 501G IP Phone   213.4800        3
# 20        Wilson Jones Hanging View Binder, White, 1"    22.7200        4
# 21                                         Newell 318    19.4600        7
# 22        Acco Six-Outlet Power Strip, 4' Cord Length    60.3400        7
# 23                 Global Deluxe Stacking Chair, Gray    71.3720        2
# 24      Bretford CR4500 Series Slim Rectangular Table  1044.6300        3
# 25                    Wilson Jones Active Use Binders    11.6480        2
# 26   Imation 8GB Mini TravelDrive USB 2.0 Flash Drive    90.5700        3
# 27  Riverside Palais Royal Lawyers Bookcase, Royal...  3083.4300        7
# 28  Avery Recycled Flexi-View Covers for Binding S...     9.6180        2
# 29  Howard Miller 13-3/4" Diameter Brushed Chrome ...   124.2000        3
# 30                          Poly String Tie Envelopes     3.2640        2
# 31  BOSTON Model 1800 Electric Pencil Sharpeners, ...    86.3040        6
# 32  Acco Pressboard Covers with Storage Hooks, 14 ...     6.8580        6
# 33                                     Lumber Crayons    15.7600        2
# 34                                  Easy-staple paper    29.4720        3
# 35                                        GE 30524EE4  1097.5440        7
# 36  Electrix Architect's Clamp-On Swing Arm Lamp, ...   190.9200        5
# 37  #10-4 1/8" x 9 1/2" Premium Diagonal Seam Enve...   113.3280        9
# 38  Atlantic Metals Mobile 3-Shelf Bookcases, Cust...   532.3992        3
# 39           Global Fabric Manager's Chair, Dark Gray   212.0580        3
# 40                    Plantronics HL10 Handset Lifter   371.1680        4
# 41                                 Panasonic Kx-TS550   147.1680        4
# 42   Eldon Base for stackable storage shelf, platinum    77.8800        2
# 43  Advantus 10-Drawer Portable Organizer, Chrome ...    95.6160        2
# 44  Verbatim 25 GB 6x Blu-ray Single Layer Recorda...    45.9800        2
# 45  Wilson Jones Leather-Like Binders with DublLoc...    17.4600        2
# 46  Gould Plastics 9-Pocket Panel Bin, 18-3/8w x 5...   211.9600        4
# 47  Imation 8gb Micro Traveldrive Usb 2.0 Flash Drive    45.0000        3
# 48  LF Elite 3D Dazzle Designer Hard Case Cover, L...    21.8000        2
# 49  C-Line Peel & Stick Add-On Filing Pockets, 8-3...    38.2200        6
#
#    Discount     Profit Unit Price
# 0      0.00    41.9136   130.9800
# 1      0.00   219.5820   243.9800
# 2      0.00     6.8714     7.3100
# 3      0.45  -383.0310   191.5155
# 4      0.20     2.5164    11.1840
# 5      0.00    14.1694     6.9800
# 6      0.00     1.9656     1.8200
# 7      0.20    90.7152   151.1920
# 8      0.20     5.7825     6.1680
# 9      0.00    34.4700    22.9800
# 10     0.20    85.3092   189.5760
# 11     0.20    68.3568   227.8560
# 12     0.20     5.4432     5.1840
# 13     0.20   132.5922   135.9920
# 14     0.80  -123.8580    13.7620
# 15     0.80    -3.8160     0.8480
# 16     0.00    13.3176   110.9800
# 17     0.00     9.9900    27.7500
# 18     0.00     2.4824     4.2800
# 19     0.20    16.0110    71.1600
# 20     0.20     7.3840     5.6800
# 21     0.00     5.0596     2.7800
# 22     0.00    15.6884     8.6200
# 23     0.30    -1.0196    35.6860
# 24     0.00   240.2649   348.2100
# 25     0.20     4.2224     5.8240
# 26     0.00    11.7741    30.1900
# 27     0.50 -1665.0522   440.4900
# 28     0.70    -7.0532     4.8090
# 29     0.20    15.5250    41.4000
# 30     0.20     1.1016     1.6320
# 31     0.20     9.7092    14.3840
# 32     0.70    -5.7150     1.1430
# 33     0.20     3.5460     7.8800
# 34     0.20     9.9468     9.8240
# 35     0.20   123.4737   156.7920
# 36     0.60  -147.9630    38.1840
# 37     0.20    35.4150    12.5920
# 38     0.32   -46.9764   177.4664
# 39     0.30   -15.1470    70.6860
# 40     0.20    41.7564    92.7920
# 41     0.20    16.5564    36.7920
# 42     0.00     3.8940    38.9400
# 43     0.20     9.5616    47.8080
# 44     0.00    19.7714    22.9900
# 45     0.00     8.2062     8.7300
# 46     0.00     8.4784    52.9900
# 47     0.00     4.9500    15.0000
# 48     0.00     6.1040    10.9000
# 49     0.00    17.9634     6.3700
#
# [50 rows x 26 columns]

# %%
# Let us save dataframe to CSV or Excel
superstore_df.to_csv("super_store_df", index=False) # for excel, it will be to_excel, extension is .xlsx

# %%
superstore_df.to_excel("/Users/Jaykay/Downloads/super_df.xlsx", index=False)
